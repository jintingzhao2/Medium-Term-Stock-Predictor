# %%
import sys

# %%
sys.path.append("src")

# %%
import stocks
# Out:
# 2026-03-15 12:18:28.712 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
stocks.get_stock_data("AAPL")
# Out:
# 2026-03-15 12:18:34.513 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-03-15 12:18:34.516 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
#                                  Open        High         Low       Close  \
# Date
# 2023-03-14 00:00:00-04:00  149.119690  151.209411  147.956548  150.410980
# 2023-03-15 00:00:00-04:00  149.030984  151.061564  147.779115  150.805283
# 2023-03-16 00:00:00-04:00  149.987097  154.225694  149.474519  153.624405
# 2023-03-17 00:00:00-04:00  153.851139  154.501718  152.076841  152.786560
# 2023-03-20 00:00:00-04:00  152.855584  155.566314  151.948708  155.152298
# ...                               ...         ...         ...         ...
# 2026-03-09 00:00:00-04:00  255.690002  261.149994  253.679993  259.880005
# ...

# %%
import yfinance as yf

# %%
aapl = yf.Ticker("AAPL")

# %%
aapl.quarterly_financials
# Out:
#                                                       2025-12-31  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.750000e-01
# Normalized EBITDA                                   5.406600e+10
# Net Income From Continuing Operation Net Minori...  4.209700e+10
# Reconciled Depreciation                             3.214000e+09
# Reconciled Cost Of Revenue                          7.452500e+10
# EBITDA                                              5.406600e+10
# EBIT                                                5.085200e+10
# Normalized Income                                   4.209700e+10
# Net Income From Continuing And Discontinued Ope...  4.209700e+10
# Total Expenses                                      9.290400e+10
# Total Operating Income As Reported                  5.085200e+10
# Diluted Average Shares                              1.481036e+10
# ...

# %%
aapl.earnings_history
# Out:
#             epsActual  epsEstimate  epsDifference  surprisePercent
# quarter
# 2025-03-31       1.65      1.62253           0.03           0.0169
# 2025-06-30       1.57      1.42572           0.14           0.1012
# 2025-09-30       1.85      1.76993           0.08           0.0452
# 2025-12-31       2.84      2.67080           0.17           0.0634

# %%
aapl.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...
